# %%
from __future__ import division

from vnpy.trader.vtConstant import *    
from vnpy.trader.app.ctaStrategy.ctaBacktesting import BacktestingEngine, MINUTE_DB_NAME, TICK_DB_NAME #ctaBase.py

# %%
print TICK_DB_NAME
from vnpy.trader.app.ctaStrategy.ctaTemplate import *
import vnpy.trader.app.ctaStrategy.strategy.TickOneStrategy
# Out:
# VnTrader_Tick_Db

# %%
if __name__ == '__main__':
    from vnpy.trader.app.ctaStrategy.strategy.TickOneStrategy import *#
    # 创建回测引擎
    engine = BacktestingEngine()
    
    # 设置引擎的回测模式为K线
    engine.setBacktestingMode(engine.TICK_MODE)

    # 设置回测用的数据起始日期
    engine.setStartDate('20180809')
    engine.setEndDate('20180809')
    
    # 设置产品相关参数
    engine.setCapital(10000)
    engine.setSize(10)
    engine.setSlippage(1)     # 股指1跳
    engine.setRate(3/10000)   # 万0.3 
    engine.setPriceTick(1)    # 股指最小价格变动
    
    # 设置使用的历史数据库
    engine.setDatabase(TICK_DB_NAME, 'rb1901') #[IF0000, rb0000]
    #engine.setDatabase('VnBitCoin', 'bitcoinTICK')
    # 在引擎中创建策略对象
    d = {}
    engine.initStrategy(TickOneStrategy)
    
    # 开始跑回测
    engine.runBacktesting()
    
    # 显示回测结果
    engine.showBacktestingResult()
# Out:
# 2018-08-14 20:02:02.936000	开始载入数据
# 最后录入数据数量： 47
# 2018-08-14 20:02:02.984000	载入完成，数据量：47
# 2018-08-14 20:02:02.984000	开始回测
# 2018-08-14 20:02:02.984000	策略初始化完成
# 2018-08-14 20:02:02.984000	策略启动完成
# 2018-08-14 20:02:02.984000	开始回放数据
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x122790D0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# <vnpy.trader.vtObject.VtTickData object at 0x14E21C50>
# <vnpy.trader.vtObject.VtTickData object at 0x14E216F0>
# 2018-08-14 20:02:03.001000	数据回放结束
# 2018-08-14 20:02:03.001000	计算回测结果
# 2018-08-14 20:02:03.001000	无交易结果
# d in show: {}
# 2018-08-14 20:02:03.002000	------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-465c8e5917d6> in <module>()
#      29
#      30     # 显示回测结果
# ---> 31     engine.showBacktestingResult()
#
# C:\Users\pc\Anaconda2_x86\lib\site-packages\vnpy-1.8.1-py2.7.egg\vnpy\trader\app\ctaStrategy\ctaBacktesting.pyc in showBacktestingResult(self)
#     801         self.output('-' * 30)
#     802         self.output(u'第一笔交易：\t%s' % d['timeList'][0])
# --> 803         self.output(u'最后一笔交易：\t%s' % d['timeList'][-1])
#     804
#     805         self.output(u'总交易次数：\t%s' % formatNumber(d['totalResult']))
#
# KeyError: 'timeList'

# %%
print engine.strategyStartDate
# Out:
# 2018-08-19 00:00:00

# %%
engine.tradeDict.values()

# %%
print (engine.tick)

# %%
if __name__ == '__main__':
    from vnpy.trader.app.ctaStrategy.strategy.TickOneStrategy import *#
    # 创建回测引擎
    engine = BacktestingEngine()
    
    # 设置引擎的回测模式为K线
    engine.setBacktestingMode(engine.TICK_MODE)

    # 设置回测用的数据起始日期
    engine.setStartDate('20180101')
    engine.setEndDate('20180102')
    
    # 设置产品相关参数
    engine.setCapital(10000)
    engine.setSize(10)
    engine.setSlippage(1)     # 股指1跳
    engine.setRate(3/10000)   # 万0.3 
    engine.setPriceTick(1)    # 股指最小价格变动
    
    # 设置使用的历史数据库
    engine.setDatabase(TICK_DB_NAME, 'bitcoin') 
    # 在引擎中创建策略对象
    d = {}
    engine.initStrategy(TickOneStrategy)
    
    # 开始跑回测
    engine.runBacktesting()
    
    # 显示回测结果
    engine.showBacktestingResult()
# Out:
# 2018-08-14 19:47:55.074000	开始载入数据
# 最后录入数据数量： 20923
# 2018-08-14 19:47:55.157000	载入完成，数据量：20923
# 2018-08-14 19:47:55.157000	开始回测
# 2018-08-14 19:47:55.157000	策略初始化完成
# 2018-08-14 19:47:55.157000	策略启动完成
# 2018-08-14 19:47:55.157000	开始回放数据
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4A9690>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C449530>
# <vnpy.trader.vtObject.VtTickData object at 0x0C370570>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4A9630>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4A9610>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442F30>
# <vnpy.trader.vtObject.VtTickData object at 0x0C442FB0>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C493070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4DC030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C4F5090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C50C070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C579030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C590090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C5EA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C601030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C617090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C672070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C689030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6A2090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6CA070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C6E0030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C75A090>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C771070>
# <vnpy.trader.vtObject.VtTickData object at 0x0C789030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C789050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C789030>
# <vnpy.trader.vtObject.VtTickData object at 0x0C789050>
# <vnpy.trader.vtObject.VtTickData object at 0x0C789030>
# ...
# <vnpy.trader.vtObject.VtTickData object at 0x120AF050>
# <vnpy.trader.vtObject.VtTickData object at 0x120AF030>
# <vnpy.trader.vtObject.VtTickData object at 0x120AF050>
# <vnpy.trader.vtObject.VtTickData object at 0x120AF030>
# <vnpy.trader.vtObject.VtTickData object at 0x120AF050>
# <vnpy.trader.vtObject.VtTickData object at 0x120AF030>
# <vnpy.trader.vtObject.VtTickData object at 0x120AF050>
# <vnpy.trader.vtObject.VtTickData object at 0x120AF030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12108030>
# <vnpy.trader.vtObject.VtTickData object at 0x12108090>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12120050>
# <vnpy.trader.vtObject.VtTickData object at 0x12120070>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12138050>
# <vnpy.trader.vtObject.VtTickData object at 0x12138030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12150030>
# <vnpy.trader.vtObject.VtTickData object at 0x12150090>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x12166050>
# <vnpy.trader.vtObject.VtTickData object at 0x12166070>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0050>
# <vnpy.trader.vtObject.VtTickData object at 0x121C0030>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6030>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6090>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6030>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6090>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6030>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6090>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6030>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6090>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6030>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6090>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6030>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6090>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6030>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6090>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6030>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6090>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6030>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6090>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6030>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6090>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6030>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6090>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6030>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6090>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6030>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6090>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6030>
# <vnpy.trader.vtObject.VtTickData object at 0x121D6090>
